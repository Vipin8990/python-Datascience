# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
pd.set_option('display.max_column', None) # sets the number of columns to display. None means all columns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/digipodium/Datasets/main/regression/automobile.csv')
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df = pd.read_csv('automobile.csv')
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.head() # if the previous line dosen't work, use this line
          # it give the value of first five record
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df  # dataframe
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# ...

# %%
df.tail() # tail give last five enteries
# Out:
#      Unnamed: 0  symboling normalized-losses   make fuel-type aspiration  \
# 200         200         -1                95  volvo       gas        std
# 201         201         -1                95  volvo       gas      turbo
# 202         202         -1                95  volvo       gas        std
# 203         203         -1                95  volvo    diesel      turbo
# 204         204         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 200         four      sedan          rwd           front       109.1   188.8
# 201         four      sedan          rwd           front       109.1   188.8
# 202         four      sedan          rwd           front       109.1   188.8
# 203         four      sedan          rwd           front       109.1   188.8
# 204         four      sedan          rwd           front       109.1   188.8
#
# ...

# %%
df.info() # it inform the data frame records and the type of values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   normalized-losses  205 non-null    object
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   num-of-doors       205 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
# ...

# %%
df.head(10)  # first 10 data frame records
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
# 5           5          2                 ?         audi       gas        std
# 6           6          1               158         audi       gas        std
# 7           7          1                 ?         audi       gas        std
# 8           8          1               158         audi       gas      turbo
# 9           9          0                 ?         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# ...

# %%
#row selection 
# indexed location (iloc)
df.iloc[0] # first row
# Out:
# Unnamed: 0                     0
# symboling                      3
# normalized-losses              ?
# make                 alfa-romero
# fuel-type                    gas
# aspiration                   std
# num-of-doors                 two
# body-style           convertible
# drive-wheels                 rwd
# engine-location            front
# wheel-base                  88.6
# length                     168.8
# width                       64.1
# height                      48.8
# curb-weight                 2548
# engine-type                 dohc
# num-of-cylinders            four
# engine-size                  130
# fuel-system                 mpfi
# bore                        3.47
# stroke                      2.68
# compression-ratio            9.0
# horsepower                   111
# peak-rpm                    5000
# city-mpg                      21
# highway-mpg                   27
# price                      13495
# Name: 0, dtype: object

# %%
df.iloc[-1] # last row
# Out:
# Unnamed: 0             204
# symboling               -1
# normalized-losses       95
# make                 volvo
# fuel-type              gas
# aspiration           turbo
# num-of-doors          four
# body-style           sedan
# drive-wheels           rwd
# engine-location      front
# wheel-base           109.1
# length               188.8
# width                 68.9
# height                55.5
# curb-weight           3062
# engine-type            ohc
# num-of-cylinders      four
# engine-size            141
# fuel-system           mpfi
# bore                  3.78
# stroke                3.15
# compression-ratio      9.5
# horsepower             114
# peak-rpm              5400
# city-mpg                19
# highway-mpg             25
# price                22625
# Name: 204, dtype: object

# %%
df.iloc[:10] # first 10 rows same as df.head(10)
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
# 5           5          2                 ?         audi       gas        std
# 6           6          1               158         audi       gas        std
# 7           7          1                 ?         audi       gas        std
# 8           8          1               158         audi       gas      turbo
# 9           9          0                 ?         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# ...

# %%
df.iloc[100:150] # rows 100 to 150
# Out:
#      Unnamed: 0  symboling normalized-losses      make fuel-type aspiration  \
# 100         100          0               106    nissan       gas        std
# 101         101          0               128    nissan       gas        std
# 102         102          0               108    nissan       gas        std
# 103         103          0               108    nissan       gas        std
# 104         104          3               194    nissan       gas        std
# 105         105          3               194    nissan       gas      turbo
# 106         106          1               231    nissan       gas        std
# 107         107          0               161    peugot       gas        std
# 108         108          0               161    peugot    diesel      turbo
# 109         109          0                 ?    peugot       gas        std
# 110         110          0                 ?    peugot    diesel      turbo
# ...

# %%
# column selection
print(df.columns.tolist()) # print the columns names
# Out:
# ['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df['make'] # to select a single column
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
df['makes'] # this will throw an error keyerror:'makes'

# %%
col_list = ['make', 'body-style']
df[col_list]
# Out:
#             make   body-style
# 0    alfa-romero  convertible
# 1    alfa-romero  convertible
# 2    alfa-romero    hatchback
# 3           audi        sedan
# 4           audi        sedan
# ..           ...          ...
# 200        volvo        sedan
# 201        volvo        sedan
# 202        volvo        sedan
# 203        volvo        sedan
# 204        volvo        sedan
#
# [205 rows x 2 columns]

# %%
df['make'].value_counts() # count the number of times each values appers in the column
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df['make'].value_counts().plot(kind='bar', figsize=(15,5), title='Automobile brands')
# Out:
# <AxesSubplot:title={'center':'Automobile brands'}>

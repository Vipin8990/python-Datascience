# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
pd.set_option('display.max_column', None) # sets the number of columns to display. None means all columns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/digipodium/Datasets/main/regression/automobile.csv')
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df = pd.read_csv('automobile.csv')
df.head()
# Out:
#    symboling  normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.head() # if the previous line dosen't work, use this line
          # it give the value of first five record
# Out:
#    symboling  normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df  # dataframe
# Out:
#      symboling  normalized-losses       brand fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 200         -1               95.0       volvo       gas        std
# 201         -1               95.0       volvo       gas      turbo
# 202         -1               95.0       volvo       gas        std
# 203         -1               95.0       volvo    diesel      turbo
# 204         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.tail() # tail give last five enteries
# Out:
#      symboling  normalized-losses  brand fuel-type aspiration num-of-doors  \
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 200      sedan          rwd           front       109.1   188.8   68.9
# 201      sedan          rwd           front       109.1   188.8   68.8
# 202      sedan          rwd           front       109.1   188.8   68.9
# 203      sedan          rwd           front       109.1   188.8   68.9
# 204      sedan          rwd           front       109.1   188.8   68.9
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
df.info() # it inform the data frame records and the type of values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   brand              205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.head(10)  # first 10 data frame records
# Out:
#    symboling  normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
# 5          2              122.0        audi       gas        std          two
# 6          1              158.0        audi       gas        std         four
# 7          1              122.0        audi       gas        std         four
# 8          1              158.0        audi       gas      turbo         four
# 9          0              122.0        audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# ...

# %%
#row selection 
# indexed location (iloc)
df.iloc[0] # first row
# Out:
# symboling                      3
# normalized-losses          122.0
# brand                 alfa-romeo
# fuel-type                    gas
# aspiration                   std
# num-of-doors                 two
# body-style           convertible
# drive-wheels                 rwd
# engine-location            front
# wheel-base                  88.6
# length                     168.8
# width                       64.1
# height                      48.8
# curb-weight                 2548
# engine-type                 dohc
# num-of-cylinders            four
# engine-size                  130
# fuel-system                 mpfi
# bore                        3.47
# stroke                      2.68
# compression-ratio            9.0
# horsepower                 111.0
# peak-rpm                  5000.0
# city-mpg                      21
# highway-mpg                   27
# price                    13495.0
# Name: 0, dtype: object

# %%
df.iloc[-1] # last row
# Out:
# symboling                 -1
# normalized-losses       95.0
# brand                  volvo
# fuel-type                gas
# aspiration             turbo
# num-of-doors            four
# body-style             sedan
# drive-wheels             rwd
# engine-location        front
# wheel-base             109.1
# length                 188.8
# width                   68.9
# height                  55.5
# curb-weight             3062
# engine-type              ohc
# num-of-cylinders        four
# engine-size              141
# fuel-system             mpfi
# bore                    3.78
# stroke                  3.15
# compression-ratio        9.5
# horsepower             114.0
# peak-rpm              5400.0
# city-mpg                  19
# highway-mpg               25
# price                22625.0
# Name: 204, dtype: object

# %%
df.iloc[:10] # first 10 rows same as df.head(10)
# Out:
#    symboling  normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
# 5          2              122.0        audi       gas        std          two
# 6          1              158.0        audi       gas        std         four
# 7          1              122.0        audi       gas        std         four
# 8          1              158.0        audi       gas      turbo         four
# 9          0              122.0        audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# ...

# %%
df.iloc[100:150] # rows 100 to 150
# Out:
#      symboling  normalized-losses     brand fuel-type aspiration num-of-doors  \
# 100          0              106.0    nissan       gas        std         four
# 101          0              128.0    nissan       gas        std         four
# 102          0              108.0    nissan       gas        std         four
# 103          0              108.0    nissan       gas        std         four
# 104          3              194.0    nissan       gas        std          two
# 105          3              194.0    nissan       gas      turbo          two
# 106          1              231.0    nissan       gas        std          two
# 107          0              161.0    peugot       gas        std         four
# 108          0              161.0    peugot    diesel      turbo         four
# 109          0              122.0    peugot       gas        std         four
# 110          0              122.0    peugot    diesel      turbo         four
# ...

# %%
# column selection
print(df.columns.tolist()) # print the columns names
# Out:
# ['symboling', 'normalized-losses', 'brand', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df['make'] # to select a single column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'make'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#df['makes'] # this will throw an error keyerror:'makes'

# %%
col_list = ['make', 'body-style']
df[col_list]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [86], line 2
#       1 col_list = ['make', 'body-style']
# ----> 2 df[col_list]
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\core\frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
# ...

# %%
df['make'].value_counts() # count the number of times each values appers in the column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'make'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['make'].value_counts().plot(kind='bar', figsize=(15,5), title='Automobile brands')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\vipin kumar\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'make'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.rename(mapper={"make":"brand"}, axis=1)
# Out:
#      Unnamed: 0  symboling normalized-losses        brand fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0          std          two  convertible          rwd           front
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.rename(mapper={"make":"brand"}, axis=1, inplace=True) # rename the column name

# %%
df.head()
# Out:
#    Unnamed: 0  symboling normalized-losses        brand fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace= True) # to delete a column

# %%
df.head()
# Out:
#    symboling normalized-losses        brand fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.replace('alfa-romero', 'alfa-romeo', inplace=True)

# %%
df
# Out:
#      symboling normalized-losses       brand fuel-type aspiration  \
# 0            3                 ?  alfa-romeo       gas        std
# 1            3                 ?  alfa-romeo       gas        std
# 2            1                 ?  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romeo       gas        std          two
# 1          3                 ?  alfa-romeo       gas        std          two
# 2          1                 ?  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
# removes all ? by np.nan
df.replace('?', np.nan, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romeo       gas        std          two
# 1          3               NaN  alfa-romeo       gas        std          two
# 2          1               NaN  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.dropna(subset=['price'])
# Out:
#      symboling normalized-losses       brand fuel-type aspiration  \
# 0            3               NaN  alfa-romeo       gas        std
# 1            3               NaN  alfa-romeo       gas        std
# 2            1               NaN  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   brand              205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.isnull().sum() # count the number of missing data in each column
# Out:
# symboling             0
# normalized-losses    41
# brand                 0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df['normalized-losses'].astype('float').sum()
# Out:
# 20008.0

# %%
df['normalized-losses'].astype('float')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
mnl = df['normalized-losses'].astype('float').mean()

# %%
df['normalized-losses'].replace(np.nan, mnl, inplace=True)
df.head()
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
mnl = df['bore'].astype('float').mean()

# %%
df['bore'].replace(np.nan, mnl, inplace=True)
df['stroke'].replace(np.nan, df['stroke'].astype('float').mean(), inplace=True)
df['horsepower'].replace(np.nan, df['horsepower'].astype('float').mean(), inplace=True)
df['peak-rpm'].replace(np.nan, df['peak-rpm'].astype('float').mean(), inplace=True)
df['price'].replace(np.nan, df['price'].astype('float').mean(), inplace=True)
df.head()

# in the place of nan fill the mean value
# Out:
#    symboling normalized-losses       brand fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romeo       gas        std          two
# 1          3             122.0  alfa-romeo       gas        std          two
# 2          1             122.0  alfa-romeo       gas        std          two
# 3          2               164        audi       gas        std         four
# 4          2               164        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df['num-of-doors'].value_counts()
# Out:
# four    116
# two      89
# Name: num-of-doors, dtype: int64

# %%
df['num-of-doors'].replace(np.nan, 'four', inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# brand                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.to_csv("automobile_cleaned.csv", index=False)

# %%
df['horsepower'] = df['horsepower'].astype('int')

# %%
df['horsepower'].plot(kind='area',figsize=(15,5), title='Horsepower')
# Out:
# <AxesSubplot:title={'center':'Horsepower'}>

# %%
df.sort_values(by='price', inplace=True, ascending=False)

# %%
df.plot(kind='scatter', x = 'horsepower', y = 'price', logy=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>
